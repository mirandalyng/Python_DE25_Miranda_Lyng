# %% [markdown]
# # 12 Matplotlib

# %% [markdown]
# better to use numpy in complications than list

# %%
import numpy as np 
import matplotlib.pyplot as plt 

x = np.linspace(-5,5)

x
# Out:
# array([-5.        , -4.79591837, -4.59183673, -4.3877551 , -4.18367347,
#        -3.97959184, -3.7755102 , -3.57142857, -3.36734694, -3.16326531,
#        -2.95918367, -2.75510204, -2.55102041, -2.34693878, -2.14285714,
#        -1.93877551, -1.73469388, -1.53061224, -1.32653061, -1.12244898,
#        -0.91836735, -0.71428571, -0.51020408, -0.30612245, -0.10204082,
#         0.10204082,  0.30612245,  0.51020408,  0.71428571,  0.91836735,
#         1.12244898,  1.32653061,  1.53061224,  1.73469388,  1.93877551,
#         2.14285714,  2.34693878,  2.55102041,  2.75510204,  2.95918367,
#         3.16326531,  3.36734694,  3.57142857,  3.7755102 ,  3.97959184,
#         4.18367347,  4.3877551 ,  4.59183673,  4.79591837,  5.        ])

# %%
x.shape
# Out:
# (50,)

# %% [markdown]
# matlab style interface

# %% [markdown]
# matlab is an other language

# %%
f = lambda x: np.sin(x)
x = np.linspace(-5,5, 100)
plt.figure(dpi = 200)
plt.plot(x, f(x)) # '--o' dashes 
plt.xlabel("x")
plt.ylabel("y")
plt.title("$\sin{x}$")
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/49/f5021v_n7cb6ghg2_c0drpn00000gn/T/ipykernel_41631/4034137626.py:7: SyntaxWarning: invalid escape sequence '\s'
#   plt.title("$\sin{x}$")
# Text(0.5, 1.0, '$\\sin{x}$')

# %% [markdown]
# oop approach

# %%
fig, ax = plt.subplots(1)

ax.plot(x, f(x))
ax.set(xlabel="x", ylabel="y", title="$\sin{x}$")
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/49/f5021v_n7cb6ghg2_c0drpn00000gn/T/ipykernel_41631/2869556476.py:4: SyntaxWarning: invalid escape sequence '\s'
#   ax.set(xlabel="x", ylabel="y", title="$\sin{x}$")
# [Text(0.5, 0, 'x'), Text(0, 0.5, 'y'), Text(0.5, 1.0, '$\\sin{x}$')]

# %% [markdown]
# subplots

# %%
fig, ax = plt.subplots(1,2, figsize=(16, 4), dpi=200)
ax[0].plot(x, np.sin(x), label="sin(x)")
ax[0].plot(x, np.cos(x), label="cos(x)")
ax[0].legend()
ax[0].set(title= "sin(x) and cos(x)", xlabel="x",ylabel="y")

ax[1].plot(x, np.cos(x))
ax[1].set(title= "cos(x)", xlabel="x", ylabel="y")
# Out:
# [Text(0.5, 1.0, 'cos(x)'), Text(0.5, 0, 'x'), Text(0, 0.5, 'y')]
